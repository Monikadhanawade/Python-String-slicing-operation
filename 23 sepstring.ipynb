# %%
s="Monika Dhanwade"
print(len(s))
print(s[-1:-16:-1]) 
print(s[0:9:3])
print(s[0:5:+1])
print(s[5:8+1:1])
print(s[0:9])
print(s[5:0:-1])
print(s[ : :-1])
print(s[ : :+1])
# Out:
# 15
# edawnahD akinoM
# Mi
# Monik
# a Dh
# Monika Dh
# akino
# edawnahD akinoM
# Monika Dhanwade

# %% [markdown]
# If we want to access multiple elements from a string then use slicing.
#
# syntax: var_name(start_index: End_index:step_value)
#
# s= "I n s t a g r a m"
#     0 1 2 3 4 5 6 7 8
#
# s=(5)-Insta
# start index=0
# end index=4
#
# ans:var=s[0:5:+1]
#
# Step_value=+1
