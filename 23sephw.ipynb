# %%
s="Monika Dhanwade"
print(len(s))
print(s[-1:-16:-1]) 
print(s[0:9:3])
print(s[0:5:+1])
print(s[5:8+1:1])

print(s[0:9])
print(s[5:0:-1])
print(s[ : :-1])
print(s[ : :+1])

print(s[1:6:+3])
print(s[7:14])
print(s[2:12:2])
print(s[1:14:3])
print(s[-1:-13:-2])

print(s[-2:-10:-2])
print(s[0:14:4])
print(s[-1:-18:-4])
print(s[-5:-15:-1])
print(s[8:15:2])
# Out:
# 15
# edawnahD akinoM
# Mi
# Monik
# a Dh
# Monika Dh
# akino
# edawnahD akinoM
# Monika Dhanwade
# ok
# Dhanwad
# nk hn
# okDnd
# eanh k
# dwaD
# Mkha
# en n
# nahD akino
# hnae
